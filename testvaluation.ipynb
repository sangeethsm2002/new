# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus.reader import wordlist
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize

# %%
data = pd.DataFrame({
    "Review": [
        "I absolutely loved this movie! The acting was amazing and I would watch it again 10 times.",
        "Terrible film. Waste of 2 hours, boring and poorly written!!!",
        "Great story, excellent visuals, and memorable characters. 2024's best movie.",
        "I didn't enjoy it. The plot was weak and the ending made no sense.",
        "Fantastic soundtrack and performances. Rating: 9/10."
    ]
})

# %%
data
# Out:
#                                               Review
# 0  I absolutely loved this movie! The acting was ...
# 1  Terrible film. Waste of 2 hours, boring and po...
# 2  Great story, excellent visuals, and memorable ...
# 3  I didn't enjoy it. The plot was weak and the e...
# 4  Fantastic soundtrack and performances. Rating:...

# %%
from nltk.stem import PorterStemmer
Ps = PorterStemmer()

# %%
text="Great story, excellent visuals, and memorable characters. 2024's best movie."

# %%
text = text.lower()
text
# Out:
# "great story, excellent visuals, and memorable characters. 2024's best movie."

# %% [markdown]
# removing number

# %%
text = re.sub(r'\d+', '', text)
text
# Out:
# "great story, excellent visuals, and memorable characters. 's best movie."

# %% [markdown]
# removing puctuations

# %%
text = re.sub(r'[^\w\s]', '', text)
text
# Out:
# 'great story excellent visuals and memorable characters s best movie'

# %% [markdown]
# tokenizing

# %%
from nltk.tokenize import word_tokenize
word_tokenize(text)
# Out:
# ['great',
#  'story',
#  'excellent',
#  'visuals',
#  'and',
#  'memorable',
#  'characters',
#  's',
#  'best',
#  'movie']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Stop words

# %%
from nltk.corpus import stopwords
word_tokens = word_tokenize(text)
filtered_sentense = [w for w in word_tokens if not w in stop_words]

filtered_sentense
# Out:
# ['sorting', 'processing', 'data', 'done', 'traditional', 'methods']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()
words = word_tokenize(text)
for w in words:
  print('original word :', w)
  print('stemmed :', wnl.lemmatize(w))
# Out:
# original word : great
# stemmed : great
# original word : story
# stemmed : story
# original word : excellent
# stemmed : excellent
# original word : visuals
# stemmed : visuals
# original word : and
# stemmed : and
# original word : memorable
# stemmed : memorable
# original word : characters
# stemmed : character
# original word : s
# stemmed : s
# original word : best
# stemmed : best
# original word : movie
# stemmed : movie

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
text = 'sorting and processing data is done by traditional methods'

words = word_tokenize(text)
for w in words:
  print('original word :', w)
  print('stemmed :', ps.stem(w))
# Out:
# original word : sorting
# stemmed : sort
# original word : and
# stemmed : and
# original word : processing
# stemmed : process
# original word : data
# stemmed : data
# original word : is
# stemmed : is
# original word : done
# stemmed : done
# original word : by
# stemmed : by
# original word : traditional
# stemmed : tradit
# original word : methods
# stemmed : method
